# %%
import json

with open(f"../../url_chunk_mapping_500.json", "r", encoding="utf-8" ) as file:
    chunk_json = json.load(file)
chunks =[]
for url in chunk_json:
    chunks.extend(chunk_json[url])

# %%
llm_augmented=[]
